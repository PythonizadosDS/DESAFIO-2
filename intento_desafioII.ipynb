# %%
#Importacion de librerias
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
bill = pd.read_csv('billboard2.csv', sep=';',encoding='latin',parse_dates=['date.entered','date.peaked'],infer_datetime_format=True)

# %%
bill.head(10)
# Out:
#        artist.inverted                                  track  time    genre  \
# 0      Destiny's Child               Independent Women Part I  3:38     Rock
# 1              Santana                           Maria, Maria  4:18     Rock
# 2        Savage Garden                     I Knew I Loved You  4:07     Rock
# 3              Madonna                                  Music  3:45     Rock
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38     Rock
# 5                Janet                  Doesn't Really Matter  4:17     Rock
# 6      Destiny's Child                            Say My Name  4:31     Rock
# 7    Iglesias, Enrique                            Be With You  3:36    Latin
# 8                Sisqo                             Incomplete  3:52     Rock
# 9             Lonestar                                 Amazed  4:25  Country
#
#   date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  x4th.week  \
# ...

# %%
for c in bill.columns:
    print ("---- %s ---" % c)
    print (bill[c].value_counts())
# Out:
# ---- artist.inverted ---
# Jay-Z                    5
# Dixie Chicks, The        4
# Houston, Whitney         4
# Spears, Britney          3
# SheDaisy                 3
# N'Sync                   3
# Jackson, Alan            3
# McGraw, Tim              3
# Price, Kelly             3
# Sisqo                    3
# Backstreet Boys, The     3
# Braxton, Toni            3
# Lonestar                 3
# Eminem                   3
# Aguilera, Christina      3
# DMX                      3
# Destiny's Child          3
# Thomas, Carl             3
# Rimes, LeAnn             3
# Limp Bizkit              3
# Martin, Ricky            3
# Vitamin C                2
# Iglesias, Enrique        2
# Eve                      2
# 3 Doors Down             2
# Simpson, Jessica         2
# Red Hot Chili Peppers    2
# Strait, George           2
# M2M                      2
# Anthony, Marc            2
#                         ..
# SoulDecision             1
# Barenaked Ladies         1
# ...

# %%
help(bill.fillna)
# Out:
# Help on method fillna in module pandas.core.frame:
#
# fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None, **kwargs) method of pandas.core.frame.DataFrame instance
#     Fill NA/NaN values using the specified method
#
#     Parameters
#     ----------
#     value : scalar, dict, Series, or DataFrame
#         Value to use to fill holes (e.g. 0), alternately a
#         dict/Series/DataFrame of values specifying which value to use for
#         each index (for a Series) or column (for a DataFrame). (values not
#         in the dict/Series/DataFrame will not be filled). This value cannot
#         be a list.
#     method : {'backfill', 'bfill', 'pad', 'ffill', None}, default None
#         Method to use for filling holes in reindexed Series
#         pad / ffill: propagate last valid observation forward to next valid
#         backfill / bfill: use NEXT valid observation to fill gap
#     axis : {0 or 'index', 1 or 'columns'}
# ...

# %%
import unidecode
def quitar_caracteres(entrada):
    return str.lower(unidecode.unidecode(entrada))

# %%
billtex=bill.iloc[:, [0,1,3]]
billtex.head()
# Out:
#        artist.inverted                                  track genre
# 0      Destiny's Child               Independent Women Part I  Rock
# 1              Santana                           Maria, Maria  Rock
# 2        Savage Garden                     I Knew I Loved You  Rock
# 3              Madonna                                  Music  Rock
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock

# %%
billtex.applymap(quitar_caracteres)
# Out:
#          artist.inverted                                              track  \
# 0        destiny's child                           independent women part i
# 1                santana                                       maria, maria
# 2          savage garden                                 i knew i loved you
# 3                madonna                                              music
# 4    aguilera, christina              come on over baby (all i want is you)
# 5                  janet                              doesn't really matter
# 6        destiny's child                                        say my name
# 7      iglesias, enrique                                        be with you
# 8                  sisqo                                         incomplete
# 9               lonestar                                             amazed
# 10                n'sync                                   it's gonna be me
# ...

# %%
bill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 82 columns):
# artist.inverted    317 non-null object
# track              317 non-null object
# time               317 non-null object
# genre              317 non-null object
# date.entered       317 non-null datetime64[ns]
# date.peaked        317 non-null datetime64[ns]
# x1st.week          317 non-null int64
# x2nd.week          312 non-null float64
# x3rd.week          307 non-null float64
# x4th.week          300 non-null float64
# x5th.week          292 non-null float64
# x6th.week          280 non-null float64
# x7th.week          269 non-null float64
# x8th.week          260 non-null float64
# x9th.week          253 non-null float64
# x10th.week         244 non-null float64
# x11th.week         236 non-null float64
# x12th.week         222 non-null float64
# x13th.week         210 non-null float64
# x14th.week         204 non-null float64
# ...

# %%
billfec=bill.iloc[:,[4,5]]

# %%
bill.iloc[:,[4,5]]
# Out:
#     date.entered date.peaked
# 0     2000-09-23  2000-11-18
# 1     2000-02-12  2000-04-08
# 2     1999-10-23  2000-01-29
# 3     2000-08-12  2000-09-16
# 4     2000-08-05  2000-10-14
# 5     2000-06-17  2000-08-26
# 6     1999-12-25  2000-03-18
# 7     2000-04-01  2000-06-24
# 8     2000-06-24  2000-08-12
# 9     1999-06-05  2000-03-04
# 10    2000-05-06  2000-07-29
# 11    1999-11-27  2000-01-15
# 12    2000-01-22  2000-07-15
# 13    2000-05-13  2000-11-11
# 14    2000-03-18  2000-06-17
# 15    2000-04-29  2000-07-22
# 16    1999-12-11  2000-02-19
# 17    1999-11-06  2000-04-22
# 18    2000-08-19  2000-12-02
# 19    2000-09-30  2000-12-30
# 20    2000-03-18  2000-05-06
# 21    2000-02-26  2000-06-03
# 22    2000-08-19  2000-09-30
# 23    2000-05-13  2000-08-19
# 24    2000-04-08  2000-11-11
# 25    2000-01-29  2000-05-20
# 26    2000-04-15  2000-07-01
# 27    1999-09-04  2000-01-08
# 28    2000-01-01  2000-07-01
# 29    1999-10-23  2000-02-12
# ..           ...         ...
# ...

# %%
type(bill.iloc[:,[4,5]])
# Out:
# pandas.core.frame.DataFrame

# %%
help(pd.to_datetime)
# Out:
# Help on function to_datetime in module pandas.core.tools.datetimes:
#
# to_datetime(arg, errors='raise', dayfirst=False, yearfirst=False, utc=None, box=True, format=None, exact=True, unit=None, infer_datetime_format=False, origin='unix')
#     Convert argument to datetime.
#
#     Parameters
#     ----------
#     arg : integer, float, string, datetime, list, tuple, 1-d array, Series
#
#         .. versionadded: 0.18.1
#
#            or DataFrame/dict-like
#
#     errors : {'ignore', 'raise', 'coerce'}, default 'raise'
#
#         - If 'raise', then invalid parsing will raise an exception
#         - If 'coerce', then invalid parsing will be set as NaT
#         - If 'ignore', then invalid parsing will return the input
#     dayfirst : boolean, default False
#         Specify a date parse order if `arg` is str or its list-likes.
#         If True, parses dates with the day first, eg 10/11/12 is parsed as
#         2012-11-10.
# ...

# %%
genre_gr=bill.groupby('genre')

# %%
genre_gr.head(8)
# Out:
#                   artist.inverted                                  track  \
# 0                 Destiny's Child               Independent Women Part I
# 1                         Santana                           Maria, Maria
# 2                   Savage Garden                     I Knew I Loved You
# 3                         Madonna                                  Music
# 4             Aguilera, Christina  Come On Over Baby (All I Want Is You)
# 5                           Janet                  Doesn't Really Matter
# 6                 Destiny's Child                            Say My Name
# 7               Iglesias, Enrique                            Be With You
# 8                           Sisqo                             Incomplete
# 9                        Lonestar                                 Amazed
# 17                    Hill, Faith                                Breathe
# 21                  Anthony, Marc                         You Sang To Me
# ...

# %%
genre_gr.get_group('Rock')
# Out:
#            artist.inverted                                  track  time genre  \
# 0          Destiny's Child               Independent Women Part I  3:38  Rock
# 1                  Santana                           Maria, Maria  4:18  Rock
# 2            Savage Garden                     I Knew I Loved You  4:07  Rock
# 3                  Madonna                                  Music  3:45  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  Rock
# 5                    Janet                  Doesn't Really Matter  4:17  Rock
# 6          Destiny's Child                            Say My Name  4:31  Rock
# 8                    Sisqo                             Incomplete  3:52  Rock
# 10                  N'Sync                       It's Gonna Be Me  3:10  Rock
# 11     Aguilera, Christina                      What A Girl Wants  3:18  Rock
# 12        Vertical Horizon                    Everything You Want  4:01  Rock
# ...

# %%
genre_gr.get_group('Latin')
# Out:
#        artist.inverted                          track  time  genre  \
# 7    Iglesias, Enrique                    Be With You  3:36  Latin
# 21       Anthony, Marc                 You Sang To Me  3:50  Latin
# 60       Martin, Ricky                      She Bangs  4:02  Latin
# 87       Martin, Ricky             Shake Your Bon-Bon  3:08  Latin
# 103        Son By Four  A Puro Dolor (Purest Of Pain)  3:30  Latin
# 128  Iglesias, Enrique                  Rhythm Divine  7:35  Latin
# 180    Lopez, Jennifer                   Feelin' Good  4:28  Latin
# 231      Martin, Ricky                Private Emotion  4:02  Latin
# 238      Anthony, Marc                    My Baby You  3:59  Latin
#
#     date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  x4th.week  \
# 7     2000-04-01  2000-06-24         63       45.0       34.0       23.0
# 21    2000-02-26  2000-06-03         77       54.0       50.0       43.0
# 60    2000-10-07  2000-12-02         38       28.0       21.0       21.0
# ...

# %%
#periodo_t=bill.iloc[:,[5]]- bill.iloc[:,[4]]

# %%
bill['Periodo_time'] = (bill['date.peaked'] - bill['date.entered']).dt.days

# %%
bill.head()
# Out:
#        artist.inverted                                  track  time genre  \
# 0      Destiny's Child               Independent Women Part I  3:38  Rock
# 1              Santana                           Maria, Maria  4:18  Rock
# 2        Savage Garden                     I Knew I Loved You  4:07  Rock
# 3              Madonna                                  Music  3:45  Rock
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  Rock
#
#   date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  x4th.week  \
# 0   2000-09-23  2000-11-18         78       63.0       49.0       33.0
# 1   2000-02-12  2000-04-08         15        8.0        6.0        5.0
# 2   1999-10-23  2000-01-29         71       48.0       43.0       31.0
# 3   2000-08-12  2000-09-16         41       23.0       18.0       14.0
# 4   2000-08-05  2000-10-14         57       47.0       45.0       29.0
#
#        ...       x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# ...

# %%
#type(bill['date.peaked'])
type(bill['date.entered'])
# Out:
# pandas.core.series.Series

# %%
#from datetime import datetime

# %%
def change_column_order(df, col_name, index):
    cols = df.columns.tolist()
    cols.remove(col_name)
    cols.insert(index, col_name)
    
    return df[cols]

# %%
df = change_column_order(bill,'Periodo_time', 6)

# %%
#Mejor ranking alcanzado
df['mejor_rank'] = df.iloc[:,7:].min(axis=1)
# Out:
# C:\Users\helen\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#total rank por  track
#df.iloc[:,7:].sum(skipna = True)
df['total_rank_tr'] =df.iloc[:,7:].sum(axis = 'columns')
# Out:
# C:\Users\helen\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df = change_column_order(df,'mejor_rank', 7)

# %%
df = change_column_order(df,'total_rank_tr', 8)

# %%
df.head(12)
# Out:
#         artist.inverted                                  track  time    genre  \
# 0       Destiny's Child               Independent Women Part I  3:38     Rock
# 1               Santana                           Maria, Maria  4:18     Rock
# 2         Savage Garden                     I Knew I Loved You  4:07     Rock
# 3               Madonna                                  Music  3:45     Rock
# 4   Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38     Rock
# 5                 Janet                  Doesn't Really Matter  4:17     Rock
# 6       Destiny's Child                            Say My Name  4:31     Rock
# 7     Iglesias, Enrique                            Be With You  3:36    Latin
# 8                 Sisqo                             Incomplete  3:52     Rock
# 9              Lonestar                                 Amazed  4:25  Country
# 10               N'Sync                       It's Gonna Be Me  3:10     Rock
# ...

# %%
help(pd.melt)
# Out:
# Help on function melt in module pandas.core.reshape.reshape:
#
# melt(frame, id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None)
#     "Unpivots" a DataFrame from wide format to long format, optionally
#     leaving identifier variables set.
#
#     This function is useful to massage a DataFrame into a format where one
#     or more columns are identifier variables (`id_vars`), while all other
#     columns, considered measured variables (`value_vars`), are "unpivoted" to
#     the row axis, leaving just two non-identifier columns, 'variable' and
#     'value'.
#
#
#     Parameters
#     ----------
#     frame : DataFrame
#     id_vars : tuple, list, or ndarray, optional
#         Column(s) to use as identifier variables.
#     value_vars : tuple, list, or ndarray, optional
#         Column(s) to unpivot. If not specified, uses all columns that
#         are not set as `id_vars`.
#     var_name : scalar
# ...

# %%
id_vars = ["artist.inverted", "track", "time", "genre",  "date.entered", "date.peaked","Periodo_time"]

# %%
bill_tidy = pd.melt(frame=df,id_vars=id_vars, var_name="week", value_name="rank")

# %%
bill_tidy.head()
# Out:
#        artist.inverted                                  track  time genre  \
# 0      Destiny's Child               Independent Women Part I  3:38  Rock
# 1              Santana                           Maria, Maria  4:18  Rock
# 2        Savage Garden                     I Knew I Loved You  4:07  Rock
# 3              Madonna                                  Music  3:45  Rock
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  Rock
#
#   date.entered date.peaked  Periodo_time        week  rank
# 0   2000-09-23  2000-11-18            56  mejor_rank   1.0
# 1   2000-02-12  2000-04-08            56  mejor_rank   1.0
# 2   1999-10-23  2000-01-29            98  mejor_rank   1.0
# 3   2000-08-12  2000-09-16            35  mejor_rank   1.0
# 4   2000-08-05  2000-10-14            70  mejor_rank   1.0

# %%
def periodo_en_semanas(x):
    semanas = x/7
    return semanas

# %%
bill_tidy["Periodo_time"] = bill_tidy["Periodo_time"].apply(periodo_en_semanas)
bill_tidy.head()
# Out:
#        artist.inverted                                  track  time genre  \
# 0      Destiny's Child               Independent Women Part I  3:38  Rock
# 1              Santana                           Maria, Maria  4:18  Rock
# 2        Savage Garden                     I Knew I Loved You  4:07  Rock
# 3              Madonna                                  Music  3:45  Rock
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  Rock
#
#   date.entered date.peaked  Periodo_time        week  rank
# 0   2000-09-23  2000-11-18           8.0  mejor_rank   1.0
# 1   2000-02-12  2000-04-08           8.0  mejor_rank   1.0
# 2   1999-10-23  2000-01-29          14.0  mejor_rank   1.0
# 3   2000-08-12  2000-09-16           5.0  mejor_rank   1.0
# 4   2000-08-05  2000-10-14          10.0  mejor_rank   1.0

# %%
# Formatting 
bill_tidy["week"] = bill_tidy["week"].str.extract('(\d+)', expand=False).astype(float)

# %%
bill_tidy["rank"] = bill_tidy["rank"].astype(float)

# %%
bill_f = bill_tidy.dropna()

# %%
bill_f['date'] = pd.to_datetime(bill_f['date.entered']) + pd.to_timedelta(bill_f['week'], unit='w') - pd.DateOffset(weeks=1)
# Out:
# C:\Users\helen\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bill_f = bill_f[[  "artist.inverted",  "track",  "time",  "genre", "week",  "rank", "date"]]
df = bill_f.sort_values(ascending=True, by=["artist.inverted","track","week","rank"])

# Assigning the tidy dataset to a variable for future usage
billboard = df

# %%
df.head(20)
# Out:
#      artist.inverted                                              track  time  \
# 563            2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 880            2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 1197           2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 1514           2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 1831           2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 2148           2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 2465           2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 604          2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 921          2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 1238         2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 341     3 Doors Down                                         Kryptonite  3:53
# ...

# %%
df.shape
# Out:
# (5307, 7)

# %%
bill.shape
# Out:
# (317, 83)

# %%
songs_cols = ["artist.inverted", "track", "time", "genre"]
songs = billboard[songs_cols].drop_duplicates()
songs = songs.reset_index(drop=True)
songs["song_id"] = songs.index
songs.head(10)
# Out:
#   artist.inverted                                              track  time  \
# 0           2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 1         2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 2    3 Doors Down                                         Kryptonite  3:53
# 3    3 Doors Down                                              Loser  4:24
# 4        504 Boyz                                      Wobble Wobble  3:35
# 5             98¡                 Give Me Just One Night (Una Noche)  3:24
# 6         A*Teens                                      Dancing Queen  3:44
# 7         Aaliyah                                      I Don't Wanna  4:15
# 8         Aaliyah                                          Try Again  4:03
# 9  Adams, Yolanda                                      Open My Heart  5:30
#
#     genre  song_id
# 0     Rap        0
# 1     R&B        1
# 2    Rock        2
# 3    Rock        3
# 4     Rap        4
# 5    Rock        5
# ...

# %%
ranks = pd.merge(billboard, songs, on=["artist.inverted", "track", "time", "genre"])
ranks = ranks[["song_id", "date","rank"]]
ranks.head(10)
# Out:
#    song_id       date  rank
# 0        0 2000-02-26  87.0
# 1        0 2000-03-04  82.0
# 2        0 2000-03-11  72.0
# 3        0 2000-03-18  77.0
# 4        0 2000-03-25  87.0
# 5        0 2000-04-01  94.0
# 6        0 2000-04-08  99.0
# 7        1 2000-09-02  91.0
# 8        1 2000-09-09  87.0
# 9        1 2000-09-16  92.0

# %%
genre_ro=bill_tidy.groupby('genre')
grock=genre_ro.get_group('Rock')

# %%
grock.head()
# Out:
#        artist.inverted                                  track  time genre  \
# 0      Destiny's Child               Independent Women Part I  3:38  Rock
# 1              Santana                           Maria, Maria  4:18  Rock
# 2        Savage Garden                     I Knew I Loved You  4:07  Rock
# 3              Madonna                                  Music  3:45  Rock
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  Rock
#
#   date.entered date.peaked  Periodo_time  week  rank
# 0   2000-09-23  2000-11-18           8.0   NaN   1.0
# 1   2000-02-12  2000-04-08           8.0   NaN   1.0
# 2   1999-10-23  2000-01-29          14.0   NaN   1.0
# 3   2000-08-12  2000-09-16           5.0   NaN   1.0
# 4   2000-08-05  2000-10-14          10.0   NaN   1.0

# %%
#contar los valores missing en cada columna
missing_values_count =grock.isnull().sum()

# %%
#Contamos el total de datos
total_cells_rock = np.product(grock.shape)

# %%
#Contamos el total de valores missing
total_missing_rock = missing_values_count.sum()

# %%
(total_missing_rock/total_cells_rock)*100
# Out:
# 8.386260941005466

# %%
#Elimino las filas missing
rock_n=grock.dropna()

# %%
rock_n.isnull().sum()
# Out:
# artist.inverted    0
# track              0
# time               0
# genre              0
# date.entered       0
# date.peaked        0
# Periodo_time       0
# week               0
# rank               0
# dtype: int64

# %%
graf_rock=rock_n.iloc[:,8]
graf1 = graf_rock.plot()
plt.xlabel("rank")
plt.ylabel("week")
#plt.grid(True)
# %matplotlib inline
plt.figure()
#plt.show(graf1)

graf1.plot(figsize=(16,8))
# Out:
# []
